# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Explore the dataset
print(netflix_df.head())
netflix_df.info()

# Filter movies released in the 1990s
netflix_90s = netflix_df[(netflix_df["release_year"]>=1990)&(netflix_df["release_year"]<=1999)]

# Explore available content types
print(netflix_90s["type"].unique())

# keep only movies
movies_90s = netflix_90s[netflix_90s["type"]=="Movie"]

# Visualize movies durations
movies_90s["duration"].hist()
plt.title("Distribution of Movies Durations in the 1990s")
plt.xlabel("Duration (minutes)")
plt.ylabel("Number of Movies")
plt.show()

# Find the most frequent movie duration
duration = int(movies_90s["duration"].mode()[0])

# Explore available movie genre
print(movies_90s["genre"].unique())

# Filter action movies
action_movies = movies_90s[movies_90s["genre"]=="Action"]

# Count action movies shorter than 90 minutes
short_movie_count = len(action_movies[action_movies["duration"] < 90])

print(duration)
print(short_movie_count)
# Out:
#   show_id  ...             genre
# 0      s2  ...            Dramas
# 1      s3  ...     Horror Movies
# 2      s4  ...            Action
# 3      s5  ...            Dramas
# 4      s6  ...  International TV
#
# [5 rows x 11 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4812 non-null   object
#  1   type          4812 non-null   object
#  2   title         4812 non-null   object
#  3   director      4812 non-null   object
#  4   cast          4812 non-null   object
#  5   country       4812 non-null   object
#  6   date_added    4812 non-null   object
#  7   release_year  4812 non-null   int64
#  8   duration      4812 non-null   int64
#  9   description   4812 non-null   object
#  10  genre         4812 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 413.7+ KB
# ['Movie' 'TV Show']
# ...
